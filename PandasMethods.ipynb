# %%
import pandas as pd

# %%
data=pd.read_csv('airlines_data_part.CSV')

# %%
data
# Out:
#              passenger_name  day  month departure_city    arrival_city  \
# 0            OLGA MELNIKOVA   27      6         Moscow         Bryansk
# 1        NATALIYA KUZNECOVA   29      6         Moscow         Bryansk
# 2             OLEG MELNIKOV   27      6         Moscow         Bryansk
# 3          VALENTIN ABRAMOV   27      6         Moscow         Bryansk
# 4            ULYANA IVANOVA   30      6         Moscow  St. Petersburg
# ...                     ...  ...    ...            ...             ...
# 1016583        ANDREY POPOV    6      8         Moscow         Bryansk
# 1016584       IRINA KARPOVA    6      8         Moscow         Bryansk
# 1016585       IRINA KARPOVA    6      8        Bryansk          Moscow
# 1016586    VLADIMIR KULIKOV    6      8        Bryansk          Moscow
# 1016587    VLADIMIR KULIKOV    6      8         Moscow         Bryansk
#
#              sales
# 0           3400.0
# 1           3700.0
# 2           3700.0
# 3           3700.0
# ...

# %%
data.head(50)
# Out:
#           passenger_name  day  month  departure_city    arrival_city   sales
# 0         OLGA MELNIKOVA   27      6          Moscow         Bryansk  3400.0
# 1     NATALIYA KUZNECOVA   29      6          Moscow         Bryansk  3700.0
# 2          OLEG MELNIKOV   27      6          Moscow         Bryansk  3700.0
# 3       VALENTIN ABRAMOV   27      6          Moscow         Bryansk  3700.0
# 4         ULYANA IVANOVA   30      6          Moscow  St. Petersburg  6000.0
# 5     SVETLANA POLYAKOVA   30      6  St. Petersburg          Moscow  6000.0
# 6       SVETLANA PAVLOVA   30      6          Moscow  St. Petersburg  6000.0
# 7       VALERIY RODIONOV   29      6          Moscow  St. Petersburg  6000.0
# 8        VASILIY FEDOROV   30      6  St. Petersburg          Moscow  6000.0
# 9     VIKTORIYA DENISOVA   29      6          Moscow  St. Petersburg  6000.0
# 10       VLADIMIR PAVLOV   29      6          Moscow  St. Petersburg  6000.0
# ...

# %%
data.columns
# Out:
# Index(['passenger_name', 'day', 'month', 'departure_city', 'arrival_city',
#        'sales'],
#       dtype='object')

# %%
data.passenger_name
# Out:
# 0              OLGA MELNIKOVA
# 1          NATALIYA KUZNECOVA
# 2               OLEG MELNIKOV
# 3            VALENTIN ABRAMOV
# 4              ULYANA IVANOVA
#                   ...
# 1016583          ANDREY POPOV
# 1016584         IRINA KARPOVA
# 1016585         IRINA KARPOVA
# 1016586      VLADIMIR KULIKOV
# 1016587      VLADIMIR KULIKOV
# Name: passenger_name, Length: 1016588, dtype: object

# %%
dataframe=data[['passenger_name','day','arrival_city']]

# %%
dataframe
# Out:
#              passenger_name  day    arrival_city
# 0            OLGA MELNIKOVA   27         Bryansk
# 1        NATALIYA KUZNECOVA   29         Bryansk
# 2             OLEG MELNIKOV   27         Bryansk
# 3          VALENTIN ABRAMOV   27         Bryansk
# 4            ULYANA IVANOVA   30  St. Petersburg
# ...                     ...  ...             ...
# 1016583        ANDREY POPOV    6         Bryansk
# 1016584       IRINA KARPOVA    6         Bryansk
# 1016585       IRINA KARPOVA    6          Moscow
# 1016586    VLADIMIR KULIKOV    6          Moscow
# 1016587    VLADIMIR KULIKOV    6         Bryansk
#
# [1016588 rows x 3 columns]

# %%
dataframe.tail()
# Out:
#            passenger_name  day arrival_city
# 1016583      ANDREY POPOV    6      Bryansk
# 1016584     IRINA KARPOVA    6      Bryansk
# 1016585     IRINA KARPOVA    6       Moscow
# 1016586  VLADIMIR KULIKOV    6       Moscow
# 1016587  VLADIMIR KULIKOV    6      Bryansk

# %%
display(data.iloc[6])
# Out:
# passenger_name    SVETLANA PAVLOVA
# day                             30
# month                            6
# departure_city              Moscow
# arrival_city        St. Petersburg
# sales                       6000.0
# Name: 6, dtype: object

# %%
dataframe.info
# Out:
# <bound method DataFrame.info of              passenger_name  day    arrival_city
# 0            OLGA MELNIKOVA   27         Bryansk
# 1        NATALIYA KUZNECOVA   29         Bryansk
# 2             OLEG MELNIKOV   27         Bryansk
# 3          VALENTIN ABRAMOV   27         Bryansk
# 4            ULYANA IVANOVA   30  St. Petersburg
# ...                     ...  ...             ...
# 1016583        ANDREY POPOV    6         Bryansk
# 1016584       IRINA KARPOVA    6         Bryansk
# 1016585       IRINA KARPOVA    6          Moscow
# 1016586    VLADIMIR KULIKOV    6          Moscow
# 1016587    VLADIMIR KULIKOV    6         Bryansk
#
# [1016588 rows x 3 columns]>

# %%
dataframe.rank()
# Out:
#          passenger_name       day  arrival_city
# 0              664216.0  896919.0       47539.5
# 1              558815.5  949286.0       47539.5
# 2              642272.5  896919.0       47539.5
# 3              840692.5  896919.0       47539.5
# 4              836702.5  979186.0      835581.0
# ...                 ...       ...           ...
# 1016583        144948.0  218006.0       47539.5
# 1016584        383059.5  218006.0       47539.5
# 1016585        383059.5  218006.0      411728.5
# 1016586        940409.0  218006.0      411728.5
# 1016587        940409.0  218006.0       47539.5
#
# [1016588 rows x 3 columns]

# %%
dataframe.tail()
# Out:
#            passenger_name  day arrival_city
# 1016583      ANDREY POPOV    6      Bryansk
# 1016584     IRINA KARPOVA    6      Bryansk
# 1016585     IRINA KARPOVA    6       Moscow
# 1016586  VLADIMIR KULIKOV    6       Moscow
# 1016587  VLADIMIR KULIKOV    6      Bryansk

# %%
display(dataframe.iloc[6])
# Out:
# passenger_name    SVETLANA PAVLOVA
# day                             30
# arrival_city        St. Petersburg
# Name: 6, dtype: object

# %%
import webbrowser

# %%
website='https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.dtypes.html'

# %%
webbrowser.open(website)
# Out:
# True
